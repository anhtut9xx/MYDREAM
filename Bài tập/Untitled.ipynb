# %%
import tkinter as tk

class EmployeeManagementForm:
    def __init__(self, master):
        self.master = master
        self.master.title("Quản lý nhân sự")
        
        # Tạo các biến lưu trữ thông tin
        self.fullname_var = tk.StringVar()
        self.address_var = tk.StringVar()
        self.department_var = tk.StringVar()
        self.salary_var = tk.StringVar()
        self.start_date_var = tk.StringVar()
        
        # Tạo các widget nhập thông tin
        tk.Label(self.master, text="Họ tên:").grid(row=0, column=0)
        tk.Entry(self.master, textvariable=self.fullname_var).grid(row=0, column=1)
        tk.Label(self.master, text="Quê quán:").grid(row=1, column=0)
        tk.Entry(self.master, textvariable=self.address_var).grid(row=1, column=1)
        tk.Label(self.master, text="Mã phòng ban:").grid(row=2, column=0)
        tk.Entry(self.master, textvariable=self.department_var).grid(row=2, column=1)
        tk.Label(self.master, text="Lương hiện tại:").grid(row=3, column=0)
        tk.Entry(self.master, textvariable=self.salary_var).grid(row=3, column=1)
        tk.Label(self.master, text="Ngày vào công ty:").grid(row=4, column=0)
        tk.Entry(self.master, textvariable=self.start_date_var).grid(row=4, column=1)
        
        # Tạo các nút chức năng
        tk.Button(self.master, text="Thêm", command=self.add_employee).grid(row=5, column=0)
        tk.Button(self.master, text="Tìm kiếm", command=self.search_employee).grid(row=5, column=1)
        tk.Button(self.master, text="Chỉnh sửa", command=self.edit_employee).grid(row=5, column=2)
        
        # Tạo kết quả tìm kiếm
        self.search_result = tk.StringVar()
        tk.Label(self.master, textvariable=self.search_result).grid(row=6, column=0, columnspan=3)
    
    def add_employee(self):
        # Lưu thông tin vào cơ sở dữ liệu
        fullname = self.fullname_var.get()
        address = self.address_var.get()
        department = self.department_var.get()
        salary = self.salary_var.get()
        start_date = self.start_date_var.get()
        # Thực hiện lưu thông tin
        # ...
        
        # Xóa các giá trị trong form
        self.fullname_var.set("")
        self.address_var.set("")
        self.department_var.set("")
        self.salary_var.set("")
        self.start_date_var.set("")
        
        # Hiển thị thông báo thành công
        tk.messagebox.showinfo("Thông báo", "Thêm nhân viên thành công!")
        
    def search_employee(self):
        # Tìm kiếm nhân viên trong cơ sở dữ liệu
        fullname = self.fullname_var.get()
        # Thực hiện tìm kiếm
        # ...

# %%
class Patient:
    def __init__(self, fullname, address, department, salary, start_date ):
        self.fullname_var = tk.StringVar()
        self.address_var = tk.StringVar()
        self.department_var = tk.StringVar()
        self.salary_var = tk.StringVar()
        self.start_date_var = tk.StringVar()
